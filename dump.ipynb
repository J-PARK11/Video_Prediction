# %%
import os
import numpy as np
from API import *
import cv2
import matplotlib.pyplot as plt
import utils
import visualization

# %%
strides = [1, 2]*10
strides
# Out:
# [1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2]

# %%
data_dir = '/home/jpark/data/'

# %%
a = dataload.load_data(data_dir,'mmnist')
# Out:
# (samples, frames, w, h, c) : (10000, 20, 64, 64, 1)

# %%
utils.set_seed(1124)
visualization.multi_frame_visualize(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 utils.set_seed(1124)
# ----> 2 visualization.multi_frame_visualize(a)
#
# File ~/project/video_pred/visualization.py:15, in multi_frame_visualize(dataset, cmap_param)
#      13 # Plot each of the sequential images for one random data example.
#      14 for idx, ax in enumerate(axes.flat):
# ---> 15     ax.imshow(np.squeeze(dataset[idx]), cmap=cmap_param)
#      16     ax.set_title(f"Frame {idx + 1}")
#      17     ax.axis("off")
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
# ...

# %%
visualization.prediction_visualize(a[0,...], a[1,...] )

# %%
f = visualization.create_videos(a)

# %%
visualization.display_video(f)
# Out:
#  Truth	Prediction
# ...

# %%
c = dataload.load_data(data_dir,'kth',20,10,0)
# Out:
# boxing 100 handclapping 99 jogging 100 handwaving 100 walking 100 running 100
# (samples, frames, w, h, c) : (599, 20, 120, 160, 3)

# %%
a1 = np.array([[1,2,3,4]])
a2 = np.array([[1,2,3,7]])
video_metric.MAE(a1,a2)
# Out:
# 0.75

# %%
learning_recorder.Recorder()

# %%
smp_path = '/home/jpark/data/kth/boxing/person07_boxing_d1_uncomp.avi'
smp_cap = data_kth.video_capture(smp_path, 40, 40, )
data_kth.print_vidcap_info(smp_cap)
# Out:
# 초당 프레임 수 25.0
# height 120.0
# width 160.0
# 총 프레임 수 : 385.0
# 현재 프레임 번호 : 40.0
# 노출 : 0.0
# 영상 길이 : 15.4 s
# 프레임 당 시간 간격 : 0.04 s

# %%
c = dataload.load_data(data_dir,'kth',20,1,50)
# Out:
# boxing 100 handclapping 99 jogging 100 handwaving 100 walking 100 running 100
# (samples, frames, w, h, c) : (599, 20, 120, 160, 3)

# %%
plt.imshow(c[10,4,:,:,:])

# %%
d = dataload.load_data(data_dir,'kth',20,5,50)
# Out:
# boxing 100 handclapping 99 jogging 100 handwaving 100 walking 100 running 100
# (samples, frames, w, h, c) : (599, 20, 120, 160, 3)

# %%
plt.imshow(d[10,3,:,:,:])
